# %% [markdown]
# # Programming Project 1 — Elliptical Arc Length (Python Version)
#
# ## Real-World Scenario
#
# Ironwood Botanical Garden is installing a new decorative elliptical trellis archway over the entrance to its rose garden. The archway's curved profile is one quarter of an ellipse, and the metal fabricator needs the exact length of curved trim material to finish one quarter-section of the arch — from the top of the arch down to where it meets the vertical support post — so the material can be ordered and cut without waste or a costly shortage on installation day.
#
# You've been brought on as a design engineering intern for the project. The garden's architect has specified the arch's proportions: a semi-major axis of **a = 11 inches** and a semi-minor axis of **b = 9 inches**. Your job is to write a Python script that calculates the arc length precisely, so the fabrication order is accurate the first time.
#
# *(This is the same underlying geometry problem as Gilat's* MATLAB: An Introduction with Applications*, Problem 1.11 — you're solving the identical arc-length calculation, just applied to a concrete design scenario and written in Python instead of MATLAB.)*

# %% [markdown]
# ## Background
#
# The arc length of a segment ABC of an ellipse with semi-major axis $a$ and semi-minor axis $b$ is given approximately by:
#
# $$L_{ABC} = \frac{1}{2}\sqrt{b^2 + 16a^2} + \frac{b^2}{8a}\ln\left(\frac{4a + \sqrt{b^2+16a^2}}{b}\right)$$
#
# Here, **A** is the point at the top of the arc (on the semi-minor axis), **C** is the point where the arc meets the semi-major axis, and **B** is a point on the curve between them.
#
# ## Learning Objectives
#
# - Translate a mathematical formula directly into working Python code
# - Use `numpy` for square root, natural log, and basic arithmetic
# - Practice clean variable naming and code organization
# - Verify a script's output against a known correct answer

# %% [markdown]
# ![Arc segment ABC of an ellipse](attachment:ellipse_arc_diagram.png)

# %% [markdown]
# ## Your Task
#
# Compute $L_{ABC}$ for the archway's dimensions (a = 11 in, b = 9 in). Fill in the `TODO` lines below.
#
# **Hints:**
# - `np.sqrt()` computes a square root; `np.log()` computes the *natural* log (this matches MATLAB's `log`, not `log10`).
# - Watch your parentheses carefully when translating the fraction $\frac{b^2}{8a}$ — it's easy to accidentally divide by just `8` instead of `8*a`.
# - Your printed answer should round to **24.5637** — use this to check your own work before submitting.

# %%
import numpy as np

# TODO: one-sentence comment explaining what this script calculates, in your own words


# Given design dimensions (inches)
a = 11
b = 9

# TODO 1: compute the term under the square root: b^2 + 16*a^2
s_squared = ...

# TODO 2: take the square root of that term (this is the "s" quantity
#         used in both parts of the formula below)
s = ...

# TODO 3: compute L_ABC using the formula above.
#         Break it into two pieces if that's easier to read:
#           term1 = s / 2
#           term2 = (b**2 / (8*a)) * np.log((4*a + s) / b)
#           L_ABC = term1 + term2
L_ABC = ...

# TODO 4: print the result, labeled and rounded to 4 decimal places
print(...)

# %% [markdown]
# ## Deliverable
#
# Submit this notebook (or an equivalent script) that:
#
# 1. Defines `a` and `b` as the given design values
# 2. Computes `L_ABC` using the formula above
# 3. Prints the result clearly labeled (e.g., `Arc length L_ABC = 24.5637 in`)
# 4. Includes a one-sentence comment at the top explaining what the script calculates, in your own words
#
# **Include all of your Python code and the printed result in your uploaded work.**
#
# ---
#
# ## Grading Notes
#
# - Full credit requires the correct numeric answer **and** working, readable code (clear variable names, no leftover `TODO` markers, appropriate comments).
# - If your answer doesn't match 24.5637, don't just adjust numbers until it matches — trace back through the formula term by term and find the actual error. This is a debugging skill you'll rely on throughout the course.
