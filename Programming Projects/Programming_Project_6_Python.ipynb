# %% [markdown]
# # Programming Project 6 — Parametric and 3D Plotting
# ## ENGR 50 — Engineering Computational Methods and Applications
#
# ---
#
# ## Real-World Scenario
#
# A drone is inspecting a cylindrical water tower. Instead of flying straight up, it follows a **spiral path** — circling outward while slowly climbing — so its camera can scan the entire curved surface. The drone's horizontal position at time $t$ is given by a parametric equation, and its height simply increases steadily with time. Your job is to plot the drone's flight path so the inspection team can review it before the flight.

# %% [markdown]
# ## Background
#
# The drone's horizontal position is given by:
#
# $$x(t) = \sqrt{t}\sin(2t) \qquad y(t) = \sqrt{t}\cos(2t)$$
#
# for $0 \leq t \leq 6\pi$.

# %% [markdown]
# ## (a) Plot x(t) and y(t) in two subplots
#
# Use the `subplot` pattern (one plot on top, one below) to show x(t) in **red** and y(t) in **blue**. Add a title, x/y-axis labels, and grid lines to each subplot.

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 6*np.pi, 500)

# TODO 1: compute x(t) and y(t)
x = ...
y = ...

# TODO 2: create two subplots (2 rows, 1 column)
plt.subplot(2, 1, 1)
# TODO: plot x vs t in red, add title, xlabel, ylabel, and grid

plt.subplot(2, 1, 2)
# TODO: plot y vs t in blue, add title, xlabel, ylabel, and grid

plt.tight_layout()
plt.show()

# %% [markdown]
# ## (b) Plot x(t) and y(t) together in one window
#
# MATLAB's `fplot` command plots a function directly over a range. Python's equivalent is simply building the `t` array with NumPy and plotting — you already have `x` and `y` computed from part (a), so this step is mostly about the plotting call itself.

# %%
# TODO: plot both x(t) and y(t) on the SAME axes (not subplots this time),
#       with a legend so it's clear which line is which

# %% [markdown]
# ## (c) Make a 3D line plot of the drone's full flight path
#
# If the drone's height is $z(t) = 0.5t$, plot x, y, and z together as a 3D curve — this is the actual path the drone flies, not just its horizontal shadow.

# %%
from mpl_toolkits.mplot3d import Axes3D

# TODO 1: compute z(t)
z = ...

# TODO 2: create a new figure with a 3D axes, plot the path, add a title and grid
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
# TODO: plot x, y, z and add a title

# %% [markdown]
# ---
#
# ## Deliverable
#
# Your completed notebook should contain all three plots (subplots, combined 2D plot, and the 3D flight path), each properly labeled.
#
# ## Grading Notes
#
# - Part (a) requires **two separate subplots**, not one plot with both lines — check that you used `plt.subplot()` (or `plt.subplots()`) correctly.
# - Part (b) requires both lines on **one** set of axes, with a legend distinguishing them.
# - Part (c) must be in a **new figure window**, separate from parts (a) and (b) — don't plot the 3D curve into the same figure as the earlier parts.
