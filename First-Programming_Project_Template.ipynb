# %% [markdown]
# # Programming Project 5 — Weekly Temperature Log Analyzer
#
# **Name:**
#
# **Date:**
#
# ---
#
# *Build the rest of this notebook yourself: add markdown cells to explain each part of your solution, and code cells to implement it. Refer to the assignment handout for the full requirements (reading the data file, classifying each day, computing the average, and writing the summary report).*
